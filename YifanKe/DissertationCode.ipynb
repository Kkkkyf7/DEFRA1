# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('2023 Pollution Inventory Dataset V2/2023 Pollution Inventory Dataset V2.xlsx', skiprows=9, engine='openpyxl')

# %%
# summarize 'REGULATED INDUSTRY SECTOR'
summary = df['REGULATED INDUSTRY SECTOR'].describe()

print(summary)
# Out:
# count        30110
# unique          17
# top       Landfill
# freq          8476
# Name: REGULATED INDUSTRY SECTOR, dtype: object

# %%
# Frequency of categories of REGULATED INDUSTRY SECTOR
value_counts = df['REGULATED INDUSTRY SECTOR'].value_counts()

# Print the amount of categories of REGULATED INDUSTRY SECTOR
num_unique_values = df['REGULATED INDUSTRY SECTOR'].nunique()
print(f"Number of categories in REGULATED INDUSTRY SECTOR: {num_unique_values}")

# Print all categories
unique_values = df['REGULATED INDUSTRY SECTOR'].unique()
print(f"The categories include: {unique_values}")

# Print the frequency of each category
print(value_counts)
# Out:
# Number of categories in REGULATED INDUSTRY SECTOR: 17
# The categories include: ['Agriculture' 'Biowaste Treatment' 'Cement and Minerals' 'Chemicals'
#  'Combustion' 'combustion' 'EfW' 'Food & Drink' 'Waste Treatment'
#  'Landfill' 'Metals' 'No Far Sector' 'Nuclear' 'Oil and Gas'
#  'Paper and textiles' 'Refineries & Fuel' 'Water Industry']
# Landfill               8476
# Water Industry         4214
# Agriculture            2978
# EfW                    2503
# Waste Treatment        2387
# Chemicals              2291
# Food & Drink           2024
# Combustion             1419
# Metals                 1260
# Biowaste Treatment      774
# Paper and textiles      487
# Refineries & Fuel       459
# Cement and Minerals     451
# Nuclear                 163
# Oil and Gas             102
# No Far Sector            88
# combustion               34
# Name: REGULATED INDUSTRY SECTOR, dtype: int64

# %%
# bar chart for REGULATED INDUSTRY SECTOR
plt.figure(figsize=(10, 6))
sns.barplot(x=value_counts.index, y=value_counts.values, palette='Set2')

# set the title and lable
plt.title('Frequency of Categories in REGULATED INDUSTRY SECTOR')
plt.xlabel('Category')
plt.ylabel('Count')

plt.xticks(rotation=90)
plt.show()

# %%
# Frequency of categories of SUB REGULATED INDUSTRY SECTOR
sub_value_counts = df['REGULATED INDUSTRY SUB SECTOR'].value_counts()

# Print the amount of categories of SUB REGULATED INDUSTRY SECTOR
sub_num_unique_values = df['REGULATED INDUSTRY SUB SECTOR'].nunique()
print(f"Number of categories in REGULATED INDUSTRY SUB SECTOR: {sub_num_unique_values}")

# Print all categories
sub_unique_values = df['REGULATED INDUSTRY SUB SECTOR'].unique()
print(f"The categories include: {sub_unique_values}")

# Print the frequency of each category
print(sub_value_counts)
# Out:
# Number of categories in REGULATED INDUSTRY SUB SECTOR: 32
# The categories include: ['Intensive Farming' 'Biowaste Treatment' 'Biowaste treatment' 'Lime'
#  'Cement' 'Minerals' 'Chemicals' 'Power' 'Other' 'Combustion' 'EfW'
#  'Food & Drink' 'Hazardous Waste' 'Non Hazardous Landfill' 'other'
#  'Inert Landfill' 'Hazardous Landfill' 'Landfill' 'Ferrous'
#  'Surface treatment' 'Non-Ferrous' 'Surface Treatment' 'Metals Recycling'
#  'No Far Sector' 'Non-Hazardous & Inert' 'Nuclear' 'Oil and Gas'
#  'Textiles' 'Paper & Pulp' 'paper & pulp' 'Refineries & Fuel'
#  'Water Industry']
# Non Hazardous Landfill    7537
# Water Industry            4214
# Intensive Farming         2978
# EfW                       2503
# Chemicals                 2291
# Food & Drink              2024
# Hazardous Waste           1843
# Power                     1405
# Biowaste Treatment         758
# Surface treatment          535
# Metals Recycling           465
# Hazardous Landfill         460
# Refineries & Fuel          459
# Non-Ferrous                359
# other                      300
# Ferrous                    291
# Paper & Pulp               287
# Cement                     193
# Textiles                   173
# Minerals                   166
# Nuclear                    163
# Inert Landfill             123
# Oil and Gas                102
# Lime                        92
# No Far Sector               88
# Non-Hazardous & Inert       79
# Surface Treatment           75
# Other                       46
# Landfill                    45
# paper & pulp                22
# Combustion                  18
# Biowaste treatment          16
# Name: REGULATED INDUSTRY SUB SECTOR, dtype: int64

# %%
# summarize 'REGULATED INDUSTRY SUB SECTOR'
summary = df['REGULATED INDUSTRY SUB SECTOR'].describe()

print(summary)
# Out:
# count                      30110
# unique                        32
# top       Non Hazardous Landfill
# freq                        7537
# Name: REGULATED INDUSTRY SUB SECTOR, dtype: object

# %%
# bar chart for SUB REGULATED INDUSTRY SECTOR
plt.figure(figsize=(10, 6))
sns.barplot(x=sub_value_counts.index, y=sub_value_counts.values, palette='Set2')

# set the title and lable
plt.title('Frequency of Categories in REGULATED INDUSTRY SUB SECTOR')
plt.xlabel('Category')
plt.ylabel('Count')

plt.xticks(rotation=90)
plt.show()

# %%
# Relationship between REGULATED INDUSTRY SECTOR and REGULATED INDUSTRY SUB SECTOR
# Refine the REGULATED INDUSTRY SECTOR, 
# and analyze the proportion of REGULATED INDUSTRY SUB SECTOR in the corresponding sector
contingency_table = pd.crosstab(df['REGULATED INDUSTRY SECTOR'], df['REGULATED INDUSTRY SUB SECTOR'])

# Print the contigency table
print(contingency_table)
# Out:
# REGULATED INDUSTRY SUB SECTOR  Biowaste Treatment  Biowaste treatment  Cement  \
# REGULATED INDUSTRY SECTOR
# Agriculture                                     0                   0       0
# Biowaste Treatment                            758                  16       0
# Cement and Minerals                             0                   0     193
# Chemicals                                       0                   0       0
# Combustion                                      0                   0       0
# EfW                                             0                   0       0
# Food & Drink                                    0                   0       0
# Landfill                                        0                   0       0
# Metals                                          0                   0       0
# No Far Sector                                   0                   0       0
# Nuclear                                         0                   0       0
# Oil and Gas                                     0                   0       0
# Paper and textiles                              0                   0       0
# Refineries & Fuel                               0                   0       0
# Waste Treatment                                 0                   0       0
# Water Industry                                  0                   0       0
# combustion                                      0                   0       0
#
# REGULATED INDUSTRY SUB SECTOR  Chemicals  Combustion   EfW  Ferrous  \
# REGULATED INDUSTRY SECTOR
# Agriculture                            0           0     0        0
# Biowaste Treatment                     0           0     0        0
# Cement and Minerals                    0           0     0        0
# Chemicals                           2291           0     0        0
# Combustion                             0          18     0        0
# EfW                                    0           0  2503        0
# Food & Drink                           0           0     0        0
# Landfill                               0           0     0        0
# Metals                                 0           0     0      291
# No Far Sector                          0           0     0        0
# Nuclear                                0           0     0        0
# Oil and Gas                            0           0     0        0
# Paper and textiles                     0           0     0        0
# Refineries & Fuel                      0           0     0        0
# Waste Treatment                        0           0     0        0
# Water Industry                         0           0     0        0
# combustion                             0           0     0        0
#
# REGULATED INDUSTRY SUB SECTOR  Food & Drink  Hazardous Landfill  \
# REGULATED INDUSTRY SECTOR
# Agriculture                               0                   0
# Biowaste Treatment                        0                   0
# Cement and Minerals                       0                   0
# Chemicals                                 0                   0
# Combustion                                0                   0
# EfW                                       0                   0
# Food & Drink                           2024                   0
# Landfill                                  0                 460
# Metals                                    0                   0
# No Far Sector                             0                   0
# Nuclear                                   0                   0
# Oil and Gas                               0                   0
# Paper and textiles                        0                   0
# Refineries & Fuel                         0                   0
# Waste Treatment                           0                   0
# Water Industry                            0                   0
# combustion                                0                   0
#
# REGULATED INDUSTRY SUB SECTOR  Hazardous Waste  ...  Other  Paper & Pulp  \
# REGULATED INDUSTRY SECTOR                       ...
# Agriculture                                  0  ...      0             0
# Biowaste Treatment                           0  ...      0             0
# Cement and Minerals                          0  ...      0             0
# Chemicals                                    0  ...      0             0
# Combustion                                   0  ...     30             0
# EfW                                          0  ...      0             0
# Food & Drink                                 0  ...      0             0
# Landfill                                     0  ...     11             0
# Metals                                       0  ...      0             0
# No Far Sector                                0  ...      0             0
# Nuclear                                      0  ...      0             0
# Oil and Gas                                  0  ...      0             0
# Paper and textiles                           0  ...      5           287
# Refineries & Fuel                            0  ...      0             0
# Waste Treatment                           1843  ...      0             0
# Water Industry                               0  ...      0             0
# combustion                                   0  ...      0             0
#
# REGULATED INDUSTRY SUB SECTOR  Power  Refineries & Fuel  Surface Treatment  \
# REGULATED INDUSTRY SECTOR
# Agriculture                        0                  0                  0
# Biowaste Treatment                 0                  0                  0
# Cement and Minerals                0                  0                  0
# Chemicals                          0                  0                  0
# Combustion                      1371                  0                  0
# EfW                                0                  0                  0
# Food & Drink                       0                  0                  0
# Landfill                           0                  0                  0
# Metals                             0                  0                 75
# No Far Sector                      0                  0                  0
# Nuclear                            0                  0                  0
# Oil and Gas                        0                  0                  0
# Paper and textiles                 0                  0                  0
# Refineries & Fuel                  0                459                  0
# Waste Treatment                    0                  0                  0
# Water Industry                     0                  0                  0
# combustion                        34                  0                  0
#
# REGULATED INDUSTRY SUB SECTOR  Surface treatment  Textiles  Water Industry  \
# REGULATED INDUSTRY SECTOR
# Agriculture                                    0         0               0
# Biowaste Treatment                             0         0               0
# Cement and Minerals                            0         0               0
# Chemicals                                      0         0               0
# Combustion                                     0         0               0
# EfW                                            0         0               0
# Food & Drink                                   0         0               0
# Landfill                                       0         0               0
# Metals                                       535         0               0
# No Far Sector                                  0         0               0
# Nuclear                                        0         0               0
# Oil and Gas                                    0         0               0
# Paper and textiles                             0       173               0
# Refineries & Fuel                              0         0               0
# Waste Treatment                                0         0               0
# Water Industry                                 0         0            4214
# combustion                                     0         0               0
#
# REGULATED INDUSTRY SUB SECTOR  other  paper & pulp
# REGULATED INDUSTRY SECTOR
# Agriculture                        0             0
# Biowaste Treatment                 0             0
# Cement and Minerals                0             0
# Chemicals                          0             0
# Combustion                         0             0
# EfW                                0             0
# Food & Drink                       0             0
# Landfill                         300             0
# Metals                             0             0
# No Far Sector                      0             0
# Nuclear                            0             0
# Oil and Gas                        0             0
# Paper and textiles                 0            22
# Refineries & Fuel                  0             0
# Waste Treatment                    0             0
# Water Industry                     0             0
# combustion                         0             0
#
# [17 rows x 32 columns]

# %%
# stacked bar chart for REGULATED INDUSTRY SECTOR vs REGULATED INDUSTRY SUB SECTOR
contingency_table.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.title('Stacked Bar Chart: REGULATED INDUSTRY SECTOR vs REGULATED INDUSTRY SUB SECTOR')
plt.xlabel('REGULATED INDUSTRY SECTOR')
plt.ylabel('Count')

plt.show()
