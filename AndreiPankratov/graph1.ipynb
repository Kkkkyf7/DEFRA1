# %%
import pandas as pd
import numpy as np
df = pd.read_excel("2023 Pollution Inventory Dataset V2.xlsx",skiprows=10)
df.head()
# Out:
#    UP3133UK                INTENSIVE FARMING; > 40,000 POULTRY  \
# 0  QP3133UM                INTENSIVE FARMING; > 40,000 POULTRY
# 1  UP3937FW   Animal vegetable and food treating etc vegetable
# 2  BN2832IK   Animal vegetable and food treating etc vegetable
# 3  AP3833US                INTENSIVE FARMING; > 40,000 POULTRY
# 4  MP3138EA  CREATED BY IED - TREATMENT AND PROCESSING (OTH...
#
#                      Fridays Ltd  \
# 0               Hook2sisters Ltd
# 1         Cawingredients Limited
# 2        Britvic Soft Drinks Plc
# 3               Hook2sisters Ltd
# 4  Muller UK & Ireland Group LLP
#
#   Chequer Tree Farm And Coursehorn Farm Poultry Unit Benenden Road Kent  \
# 0  Winfarthing Farm Poultry Unit Short Green Winf...
# 1  Caw House Conygarth Way Leeming Bar Business P...
# 2  Beckton Soft Drinks Factory 9 Roding Road Lond...
# 3  Martham East Farm Poultry Unit Rollesby Road M...
# 4           Minsterley Dairy Station Road Shropshire
#
# ...
