# %%
import pandas as pd
import os

# Folder containing the Excel files (use '.' if they're in the current working directory)
folder_path = "."

# List of Excel filenames based on original DataFrame names
file_names = [
    "df_no_gas.xlsx", "df22_no_gas.xlsx", "df21_no_gas.xlsx", "df20_no_gas.xlsx",
    "df19_no_gas.xlsx", "df18_no_gas.xlsx", "df17_no_gas.xlsx", "df16_no_gas.xlsx"
]

# Dictionary to store loaded DataFrames
dfs = {}

# Read each Excel file into a DataFrame
for file in file_names:
    file_path = os.path.join(folder_path, file)
    df_name = file.replace(".xlsx", "")
    dfs[df_name] = pd.read_excel(file_path)

# Optionally display the keys (i.e., DataFrame names)
print("Loaded DataFrames:")
print(list(dfs.keys()))
# Out:
# Loaded DataFrames:
# ['df_no_gas', 'df22_no_gas', 'df21_no_gas', 'df20_no_gas', 'df19_no_gas', 'df18_no_gas', 'df17_no_gas', 'df16_no_gas']

# %%
globals().update(dfs)
print(len(df_no_gas))
print(len(df22_no_gas))
print(len(df21_no_gas))
print(len(df20_no_gas))
print(len(df19_no_gas))
print(len(df18_no_gas))
print(len(df17_no_gas))
# Out:
# 12506
# 13329
# 13777
# 13227
# 13936
# 13372
# 13047

# %%
for name in dfs:
    # Remove 'Chlorides - as Cl' from the original DataFrame
    dfs[name] = dfs[name][dfs[name]["SUBSTANCE NAME"] != "Chlorides - as Cl"]

for name, df in dfs.items():
    print(f"\n{name} - Total kg released by substance (sorted):\n")
    
    # Group by substance name and sum the kg released
    grouped = df.groupby("SUBSTANCE NAME", as_index=False)["QUANTITY RELEASED (kg)"].sum()
    
    # Sort in descending order of kg released
    sorted_grouped = grouped.sort_values(by="QUANTITY RELEASED (kg)", ascending=False)
    
    print(sorted_grouped)
# Out:
# df_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68              Total organic carbon (TOC)            5.474413e+07
# 61                 Phosphorus - as total P            9.140945e+06
# 37                        Fluorides - as F            1.566672e+06
# 38  Halogenated organic compounds - as AOX            4.355960e+05
# 60                    Phenols - total as C            4.015030e+05
# ..                                     ...                     ...
# 35        Ethylene oxide (1,2 Epoxyethane)            0.000000e+00
# 16                         Chlorfenvinphos            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 39                              Heptachlor            0.000000e+00
#
# [78 rows x 2 columns]
#
# df22_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68              Total organic carbon (TOC)            7.034295e+07
# 61                 Phosphorus - as total P            1.187479e+07
# 37                        Fluorides - as F            1.626633e+06
# 38  Halogenated organic compounds - as AOX            4.183150e+05
# 77                                    Zinc            1.724435e+05
# ..                                     ...                     ...
# 18                            Chlorpyrifos            0.000000e+00
# 16                         Chlorfenvinphos            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 39                              Heptachlor            0.000000e+00
#
# [78 rows x 2 columns]
#
# df21_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68              Total organic carbon (TOC)            7.674133e+07
# 61                 Phosphorus - as total P            1.086053e+07
# 37                        Fluorides - as F            1.435649e+06
# 38  Halogenated organic compounds - as AOX            4.731990e+05
# 77                                    Zinc            2.002208e+05
# ..                                     ...                     ...
# 18                            Chlorpyrifos            0.000000e+00
# 16                         Chlorfenvinphos            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 39                              Heptachlor            0.000000e+00
#
# [78 rows x 2 columns]
#
# df20_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68              Total organic carbon (TOC)            6.289229e+07
# 61                 Phosphorus - as total P            1.014285e+07
# 37                        Fluorides - as F            1.294359e+06
# 38  Halogenated organic compounds - as AOX            4.373550e+05
# 77                                    Zinc            1.771305e+05
# ..                                     ...                     ...
# 16                         Chlorfenvinphos            0.000000e+00
# 74     Triphenyltin and compounds - as TPT            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 0                                 Alachlor            0.000000e+00
#
# [78 rows x 2 columns]
#
# df19_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 69              Total organic carbon (TOC)            7.674343e+07
# 62                 Phosphorus - as total P            9.990753e+06
# 37                        Fluorides - as F            1.538709e+06
# 38  Halogenated organic compounds - as AOX            4.115140e+05
# 46                                    Iron            2.841630e+05
# ..                                     ...                     ...
# 35        Ethylene oxide (1,2 Epoxyethane)            0.000000e+00
# 16                         Chlorfenvinphos            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 39                              Heptachlor            0.000000e+00
#
# [79 rows x 2 columns]
#
# df18_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68              Total organic carbon (TOC)            7.375927e+07
# 61                 Phosphorus - as total P            1.025540e+07
# 37                        Fluorides - as F            1.781883e+06
# 38  Halogenated organic compounds - as AOX            4.068390e+05
# 77                                    Zinc            1.933658e+05
# ..                                     ...                     ...
# 18                            Chlorpyrifos            0.000000e+00
# 16                         Chlorfenvinphos            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 39                              Heptachlor            0.000000e+00
#
# [78 rows x 2 columns]
#
# df17_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68              Total organic carbon (TOC)            7.690696e+07
# 61                 Phosphorus - as total P            1.024715e+07
# 37                        Fluorides - as F            1.769885e+06
# 38  Halogenated organic compounds - as AOX            4.058630e+05
# 77                                    Zinc            1.900699e+05
# ..                                     ...                     ...
# 35        Ethylene oxide (1,2 Epoxyethane)            0.000000e+00
# 16                         Chlorfenvinphos            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 39                              Heptachlor            0.000000e+00
#
# [78 rows x 2 columns]
#
# df16_no_gas - Total kg released by substance (sorted):
#
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68              Total organic carbon (TOC)            8.612863e+07
# 61                 Phosphorus - as total P            1.101726e+07
# 37                        Fluorides - as F            1.708546e+06
# 38  Halogenated organic compounds - as AOX            4.397170e+05
# 77                                    Zinc            2.039069e+05
# ..                                     ...                     ...
# 35        Ethylene oxide (1,2 Epoxyethane)            0.000000e+00
# 16                         Chlorfenvinphos            0.000000e+00
# 15                             Chlordecone            0.000000e+00
# 14                               Chlordane            0.000000e+00
# 39                              Heptachlor            0.000000e+00
#
# [78 rows x 2 columns]

# %%
for name, df in dfs.items():
    print(f"\n{name} - Substances with non-zero total release:\n")
    
    # Group by substance and sum the quantity released
    grouped = df.groupby("SUBSTANCE NAME", as_index=False)["QUANTITY RELEASED (kg)"].sum()
    
    # Filter out substances with total = 0
    non_zero = grouped[grouped["QUANTITY RELEASED (kg)"] > 0]
    
    # Sort by quantity released, descending
    sorted_non_zero = non_zero.sort_values(by="QUANTITY RELEASED (kg)", ascending=False)
    
    print(sorted_non_zero)
# Out:
# df_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68                     Total organic carbon (TOC)            5.474413e+07
# 61                        Phosphorus - as total P            9.140945e+06
# 37                               Fluorides - as F            1.566672e+06
# 38         Halogenated organic compounds - as AOX            4.355960e+05
# 60                           Phenols - total as C            4.015030e+05
# ..                                            ...                     ...
# 73                                    Trifluralin            3.671000e-02
# 46                                        Isodrin            1.285000e-02
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            4.295000e-03
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            4.295000e-03
# 63  Polychlorinated biphenyls (PCBs) - as WHO TEQ            4.000000e-05
#
# [63 rows x 2 columns]
#
# df22_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68                     Total organic carbon (TOC)            7.034295e+07
# 61                        Phosphorus - as total P            1.187479e+07
# 37                               Fluorides - as F            1.626633e+06
# 38         Halogenated organic compounds - as AOX            4.183150e+05
# 77                                           Zinc            1.724435e+05
# ..                                            ...                     ...
# 46                                        Isodrin            2.710000e-02
# 62               Polychlorinated biphenyls (PCBs)            1.632000e-02
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            3.671000e-03
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            3.671000e-03
# 63  Polychlorinated biphenyls (PCBs) - as WHO TEQ            3.000000e-04
#
# [62 rows x 2 columns]
#
# df21_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68                     Total organic carbon (TOC)            7.674133e+07
# 61                        Phosphorus - as total P            1.086053e+07
# 37                               Fluorides - as F            1.435649e+06
# 38         Halogenated organic compounds - as AOX            4.731990e+05
# 77                                           Zinc            2.002208e+05
# ..                                            ...                     ...
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            4.675000e-03
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            4.675000e-03
# 46                                        Isodrin            4.380000e-03
# 62               Polychlorinated biphenyls (PCBs)            2.760000e-03
# 63  Polychlorinated biphenyls (PCBs) - as WHO TEQ            8.200000e-04
#
# [62 rows x 2 columns]
#
# df20_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68                     Total organic carbon (TOC)            6.289229e+07
# 61                        Phosphorus - as total P            1.014285e+07
# 37                               Fluorides - as F            1.294359e+06
# 38         Halogenated organic compounds - as AOX            4.373550e+05
# 77                                           Zinc            1.771305e+05
# ..                                            ...                     ...
# 62               Polychlorinated biphenyls (PCBs)            7.280000e-03
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            4.206000e-03
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            4.206000e-03
# 63  Polychlorinated biphenyls (PCBs) - as WHO TEQ            2.280000e-03
# 46                                        Isodrin            1.150000e-03
#
# [65 rows x 2 columns]
#
# df19_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 69                     Total organic carbon (TOC)            7.674343e+07
# 62                        Phosphorus - as total P            9.990753e+06
# 37                               Fluorides - as F            1.538709e+06
# 38         Halogenated organic compounds - as AOX            4.115140e+05
# 46                                           Iron            2.841630e+05
# ..                                            ...                     ...
# 1                                          Aldrin            1.012500e-01
# 27                                       Dieldrin            8.077000e-02
# 47                                        Isodrin            5.126000e-02
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            3.988000e-03
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            3.988000e-03
#
# [64 rows x 2 columns]
#
# df18_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68                     Total organic carbon (TOC)            7.375927e+07
# 61                        Phosphorus - as total P            1.025540e+07
# 37                               Fluorides - as F            1.781883e+06
# 38         Halogenated organic compounds - as AOX            4.068390e+05
# 77                                           Zinc            1.933658e+05
# ..                                            ...                     ...
# 44       Hexachlorocyclohexane (HCH) -all isomers            2.200000e-02
# 46                                        Isodrin            1.406000e-02
# 26                                     Dichlorvos            1.277000e-02
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            3.731000e-03
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            3.731000e-03
#
# [62 rows x 2 columns]
#
# df17_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68                     Total organic carbon (TOC)            7.690696e+07
# 61                        Phosphorus - as total P            1.024715e+07
# 37                               Fluorides - as F            1.769885e+06
# 38         Halogenated organic compounds - as AOX            4.058630e+05
# 77                                           Zinc            1.900699e+05
# ..                                            ...                     ...
# 1                                          Aldrin            1.201000e-02
# 18                                   Chlorpyrifos            1.000000e-02
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            3.918000e-03
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            3.878000e-03
# 46                                        Isodrin            1.700000e-03
#
# [62 rows x 2 columns]
#
# df16_no_gas - Substances with non-zero total release:
#
#                                    SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 68                     Total organic carbon (TOC)            8.612863e+07
# 61                        Phosphorus - as total P            1.101726e+07
# 37                               Fluorides - as F            1.708546e+06
# 38         Halogenated organic compounds - as AOX            4.397170e+05
# 77                                           Zinc            2.039069e+05
# ..                                            ...                     ...
# 73                                    Trifluralin            1.512000e-02
# 27                                       Dieldrin            1.492000e-02
# 46                                        Isodrin            1.098000e-02
# 28     Dioxins and furans (PCDDs/PCDFs) - as ITEQ            4.297000e-03
# 29  Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ            4.297000e-03
#
# [62 rows x 2 columns]

# %%
print(df18_no_gas["SUBSTANCE NAME"].unique())
# Out:
# ['Zinc' 'Chlorides - as Cl' 'Total organic carbon (TOC)' 'Copper' 'Lead'
#  'Arsenic' 'Cadmium' 'Chromium' 'Asbestos' 'Alachlor' 'Anthracene'
#  'Benzo(g,h,i)perylene' 'Chlordane' 'Chlordecone' 'Chlorfenvinphos'
#  'Ethylene oxide (1,2 Epoxyethane)' 'Fluoranthene' 'Heptachlor'
#  'Hexabromobiphenyl' 'Isodrin' 'Lindane' 'Mirex' 'Pentachlorobenzene'
#  'Perfluoro octanyl sulphate (PFOS)' 'Tetrachloroethylene (PER)'
#  'Toxaphene' 'Trichloroethylene' 'Vinyl chloride'
#  'Dioxins and furans (PCDDs/PCDFs) - as ITEQ'
#  'Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ'
#  'Triphenyltin and compounds - as TPT'
#  'Hexachlorocyclohexane (HCH) -all isomers' 'Hexachlorobutadiene' 'Aldrin'
#  'Atrazine' 'Dichlorodiphenyltrichloroethane (DDT)' 'Dichlorvos'
#  'Dieldrin' 'Hexachlorobenzene (HCB)' 'Chlorpyrifos' 'Ethyl benzene'
#  'Endosulfan' 'Endrin' 'Naphthalene' 'Pentachlorophenol (PCP)' 'Simazine'
#  'Tributyltin and compounds - as TBT' 'Trifluralin' 'Benzene'
#  'Carbon tetrachloride (Tetrachloromethane)'
#  'Chloroform (Trichloromethane)'
#  'Ethylene dichloride (1,2-Dichloroethane)' 'Toluene'
#  'Trichlorobenzene - all isomers' 'Xylene - all isomers' 'Mercury'
#  'Indeno(1,2,3-cd)pyrene' 'Dichloromethane (DCM) (Methylene chloride)'
#  'Nickel' 'Benzo(a)pyrene' 'Benzo(b)fluoranthene' 'Benzo(k)fluoranthene'
#  'Nonylphenols and nonylphenol ethoxylates'
#  'Octylphenols and octylphenol ethoxylates'
#  'Polychlorinated biphenyls (PCBs) - as WHO TEQ' 'Cypermethrin' 'Diuron'
#  'Di(2-ethylhexyl)phthalate (DEHP)' 'Hexabromocyclododecane' 'Isoproturon'
#  'Brominated diphenylethers - penta-, octa- and deca- BDE'
#  'Cyanides - as CN' 'Fluorides - as F'
#  'Halogenated organic compounds - as AOX' 'Organotin compounds - as Sn'
#  'Phenols - total as C' 'Phosphorus - as total P'
#  'Polychlorinated biphenyls (PCBs)'
#  'Short chain (C10-13) chlorinated paraffins (SCCPs)']

# %%
# # List of substances of interest
# #target_substances = [
#     "Phosphorus - as total P",
#     "Mercury",
#     "Nickel",
#     "Zinc",
#     "Cadmium",
#     "Arsenic",
#     "Copper",
#     "Chromium",
#     "Lead",
#     "Napthalene",
#     "Benzene",
#     "Toluene",
#     "Xylene - all isomers",
#     "Di(2-ethylhexyl)phthalate (DEHP)",
#     "Tetrachloroethylene (PER)",
#     "Carbon tetrachloride (Tetrachloromethane)",
#     "Diuron",
#     "Trichloroethylene",
#     "Chloroform (Trichloromethane)",
#     "Ethylene dichloride (1,2-Dichloroethane)",
#     "Dichloromethane (DCM) (Methylene chloride)",
#     "Cypermethrin"
# ]

# # List of DataFrame variable names
# df_names = [
#     "df_no_gas", "df22_no_gas", "df21_no_gas", "df20_no_gas",
#     "df19_no_gas", "df18_no_gas", "df17_no_gas", "df16_no_gas"
# ]

# # Loop through and filter each DataFrame in-place
# for name in df_names:
#     df = globals()[name]  # get the DataFrame object by name
#     # Filter for exact matches (case-insensitive)
#     filtered_df = df[df["SUBSTANCE NAME"].str.lower().isin([s.lower() for s in target_substances])]
#     globals()[name] = filtered_df  # overwrite the original DataFrame

# %%
# List of DataFrame names
df_names = [
    "df_no_gas", "df22_no_gas", "df21_no_gas", "df20_no_gas",
    "df19_no_gas", "df18_no_gas", "df17_no_gas", "df16_no_gas"
]

# Concatenate all DataFrames into one
all_data = pd.concat([globals()[name] for name in df_names], ignore_index=True)

# Group by substance and sum total kg released
total_combined = all_data.groupby("SUBSTANCE NAME", as_index=False)["QUANTITY RELEASED (kg)"].sum()

# Sort descending
total_combined = total_combined.sort_values(by="QUANTITY RELEASED (kg)", ascending=False)

# Display result
print(total_combined)
# Out:
#                             SUBSTANCE NAME  QUANTITY RELEASED (kg)
# 17                       Chlorides - as Cl            7.114839e+09
# 70              Total organic carbon (TOC)            5.782590e+08
# 63                 Phosphorus - as total P            8.352969e+07
# 38                        Fluorides - as F            1.272234e+07
# 39  Halogenated organic compounds - as AOX            3.428398e+06
# ..                                     ...                     ...
# 36        Ethylene oxide (1,2 Epoxyethane)            0.000000e+00
# 41                       Hexabromobiphenyl            0.000000e+00
# 42                  Hexabromocyclododecane            0.000000e+00
# 59                      Pentachlorobenzene            0.000000e+00
# 0                                 Alachlor            0.000000e+00
#
# [80 rows x 2 columns]

# %%
# # Loop through and filter each DataFrame in-place
# for name in df_names:
#     df = globals()[name]  # get the DataFrame object by name
#     filtered_df = df[df["SUBSTANCE NAME"].str.lower().isin([s.lower() for s in target_substances])]
#     globals()[name] = filtered_df  # overwrite the original DataFrame

# %%
# 1. Define PNEC values and units
pnec_data = {
    "Phosphorus": ("2.5", "ng/L"),
    "Mercury": ("0.057", "µg/L"),
    "Nickel": ("6.1", "µg/L"),
    "Zinc": ("19.7", "µg/L"),
    "Cadmium": ("0.19", "µg/L"),
    "Arsenic": ("5.6", "µg/L"),
    "Copper": ("6.3", "µg/L"),
    "Chromium": ("6.5", "µg/L"),
    "Lead": ("3.3", "µg/L"),
    "Napthalene": ("2.4", "µg/L"),
    "Benzene": ("80", "µg/L"),
    "Toluene": ("0.68", "mg/L"),
    "Xylene": ("0.044", "mg/L"),
    "Bis(2-ethylhexyl) phthalate": ("100", "mg/kg"),
    "Tetrachloroethylene": ("0.051", "mg/L"),
    "Carbon tetrachloride (Tetrachloromethane)": ("0.036", "mg/L"),
    "Diuron": ("0.32", "µg/L"),
    "Trichloroethylene": ("0.576", "mg/L"),
    "Chloroform (Trichloromethane)": ("0.146", "mg/L"),
    "Ethylene dichloride (1,2-Dichloroethane)": ("1.1", "mg/L"),
    "Dichloromethane (DCM) (Methylene chloride)": ("0.31", "mg/L"),
    "Cypermethrin": ("0.013", "ng/L")
}

# 2. Unit conversion factors to µg/L
unit_conversion = {
    "ng/L": 1e-3,
    "µg/L": 1,
    "mg/L": 1e3,
    "mg/kg": None  # can't compare sediment to water directly
}

# 3. Build a lookup dictionary with standard units
pnec_ugL = {}
for substance, (val, unit) in pnec_data.items():
    val = float(val)
    key = substance.lower()
    if unit_conversion[unit] is not None:
        pnec_ugL[key] = val * unit_conversion[unit]
    else:
        pnec_ugL[key] = None  # or drop if irrelevant

# 4. List of your dataframe names
df_names = [
    "df_no_gas", "df22_no_gas", "df21_no_gas", "df20_no_gas",
    "df19_no_gas", "df18_no_gas", "df17_no_gas", "df16_no_gas"
]

# 5. Add PNEC column to each DataFrame
for name in df_names:
    df = globals()[name]
    df["PNEC (µg/L)"] = df["SUBSTANCE NAME"].str.lower().map(pnec_ugL)
    globals()[name] = df  # update the variable

# %%
# 6. Combine all dataframes into one
combined_df = pd.concat([globals()[name] for name in df_names], ignore_index=True)

# 7. Group by substance and PNEC, then sum quantity released
totals = (
    combined_df
    .groupby(["SUBSTANCE NAME", "PNEC (µg/L)"], as_index=False)["QUANTITY RELEASED (kg)"]
    .sum()
)

# 8. Calculate Release-to-PNEC ratio
totals["Release_to_PNEC_Ratio"] = totals["QUANTITY RELEASED (kg)"] / totals["PNEC (µg/L)"]

# 9. Sort from highest to lowest ratio
totals_sorted = totals.sort_values(by="Release_to_PNEC_Ratio", ascending=False)

# 10. Print results
print(totals_sorted[["SUBSTANCE NAME", "QUANTITY RELEASED (kg)", "PNEC (µg/L)", "Release_to_PNEC_Ratio"]])
# Out:
#                                 SUBSTANCE NAME  QUANTITY RELEASED (kg)  \
# 7                                 Cypermethrin            1.497953e+02
# 16                                        Zinc            1.515968e+06
# 6                                       Copper            3.908469e+05
# 13                                      Nickel            2.762941e+05
# 12                                     Mercury            1.647387e+03
# 2                                      Cadmium            4.890055e+03
# 11                                        Lead            5.259549e+04
# 5                                     Chromium            5.920325e+04
# 0                                      Arsenic            4.315968e+04
# 9                                       Diuron            2.219311e+03
# 1                                      Benzene            1.444441e+05
# 14                                     Toluene            1.087779e+05
# 4                Chloroform (Trichloromethane)            1.292030e+04
# 8   Dichloromethane (DCM) (Methylene chloride)            1.249551e+04
# 3    Carbon tetrachloride (Tetrachloromethane)            2.588145e+02
# 15                           Trichloroethylene            1.536640e+03
# 10    Ethylene dichloride (1,2-Dichloroethane)            5.566620e+02
#
#     PNEC (µg/L)  Release_to_PNEC_Ratio
# 7      0.000013           1.152272e+07
# 16    19.700000           7.695267e+04
# 6      6.300000           6.203919e+04
# 13     6.100000           4.529411e+04
# 12     0.057000           2.890152e+04
# 2      0.190000           2.573713e+04
# 11     3.300000           1.593803e+04
# 5      6.500000           9.108193e+03
# 0      5.600000           7.707085e+03
# 9      0.320000           6.935346e+03
# 1     80.000000           1.805551e+03
# 14   680.000000           1.599675e+02
# 4    146.000000           8.849518e+01
# 8    310.000000           4.030810e+01
# 3     36.000000           7.189292e+00
# 15   576.000000           2.667778e+00
# 10  1100.000000           5.060564e-01

# %%
# file_names = [
#     "df_no_gas.xlsx", "df22_no_gas.xlsx", "df21_no_gas.xlsx", "df20_no_gas.xlsx",
#     "df19_no_gas.xlsx", "df18_no_gas.xlsx", "df17_no_gas.xlsx", "df16_no_gas.xlsx"
# ]

# # Dictionary to store loaded DataFrames
# dfs = {}

# # Read each Excel file into a DataFrame
# for file in file_names:
#     file_path = os.path.join(folder_path, file)
#     df_name = file.replace(".xlsx", "")
#     dfs[df_name] = pd.read_excel(file_path)

# %%
# combined_df2 = pd.concat([globals()[name] for name in df_names], ignore_index=True)
# #From combined pollution data
# print(combined_df2["SUBSTANCE NAME"].unique())

# # From Norman_PNEC.csv
# print(pnec_df["ChemName_in_Table"].unique())
# #Phosphorus - as total P

# %%
# Step 4: Load PNEC data
pnec_df = pd.read_csv("Norman_PNEC.csv")
pnec_df["ChemName_in_Table"] = pnec_df["ChemName_in_Table"].astype(str).str.strip()

name_fixes = {
    "endrin ": "endrin",
    "beta-hexachlorocyclohexane (b-hch)": "hexachlorocyclohexane (hch) -all isomers",
    "p-xylene": "xylene - all isomers",
    "tetrachloroethylene": "tetrachloroethylene (per)",
    "dichloromethane": "dichloromethane (dcm) (methylene chloride)",
    "cyanide": "cyanides - as cn",
    "fluoride": "fluorides - as f",
    "phenol": "phenols - total as c",
    "di(2-ethylhexyl)phthalate (dehp)": "di(2-ethylhexyl)phthalate (dehp)",
    "ethylbenzene": "ethyl benzene",
    "pentachlorophenol": "pentachlorophenol (pcp)",
    "trichlorobenzenes": "trichlorobenzene - all isomers"
}
# Lowercase and replace based on the fixes
pnec_df["substance_lower"] = (
    pnec_df["ChemName_in_Table"].str.lower().replace(name_fixes)
)
print("substance_lower" in pnec_df.columns)
print(pnec_df.columns)
# Out:
# True
# Index(['ChemName_in_Image', 'ChemName_in_Table', 'PNEC', 'Date',
#        'substance_lower'],
#       dtype='object')

# %%
combined_df = pd.concat([globals()[name] for name in df_names], ignore_index=True)

# Step 2: Clean substance and quantity columns
combined_df["SUBSTANCE NAME"] = combined_df["SUBSTANCE NAME"].astype(str)
combined_df["QUANTITY RELEASED (kg)"] = pd.to_numeric(
    combined_df["QUANTITY RELEASED (kg)"], errors="coerce"
).fillna(0)
combined_df["substance_lower"] = combined_df["SUBSTANCE NAME"].str.lower()

# Step 3: Sum quantity released per substance
release_totals = (
    combined_df.groupby(["substance_lower", "SUBSTANCE NAME"], as_index=False)["QUANTITY RELEASED (kg)"]
    .sum()
)

# Step 5: Merge totals with PNEC data
merged = release_totals.merge(
    pnec_df[["substance_lower", "PNEC"]],
    on="substance_lower",
    how="left"
)

# Convert PNEC column to numeric
merged["PNEC"] = pd.to_numeric(merged["PNEC"], errors="coerce")
# Step 6: Calculate the ratio where PNEC exists
merged["Release_to_PNEC_Ratio"] = merged.apply(
    lambda row: row["QUANTITY RELEASED (kg)"] / row["PNEC"] if pd.notnull(row["PNEC"]) else None,
    axis=1
)

# Step 7: Sort and display
merged_sorted = merged.sort_values(by="Release_to_PNEC_Ratio", ascending=False)

# Show key columns
print(merged_sorted[["SUBSTANCE NAME", "QUANTITY RELEASED (kg)", "PNEC", "Release_to_PNEC_Ratio"]])
# Out:
#                                        SUBSTANCE NAME  QUANTITY RELEASED (kg)  \
# 40                                         Heptachlor            2.316930e+00
# 46                             Indeno(1,2,3-cd)pyrene            1.160193e+03
# 7                                      Benzo(a)pyrene            9.410344e+02
# 23                                       Cypermethrin            1.497953e+02
# 37                                       Fluoranthene            4.241954e+02
# ..                                                ...                     ...
# 66  Short chain (C10-13) chlorinated paraffins (SC...            0.000000e+00
# 70                         Total organic carbon (TOC)            5.782590e+08
# 71                                          Toxaphene            0.000000e+00
# 72                 Tributyltin and compounds - as TBT            2.096376e+01
# 76                Triphenyltin and compounds - as TPT            3.900000e-01
#
#             PNEC  Release_to_PNEC_Ratio
# 40  1.700000e-07           1.362900e+07
# 46  1.700000e-04           6.824666e+06
# 7   1.700000e-04           5.535497e+06
# 23  3.000000e-05           4.993177e+06
# 37  7.620000e-04           5.566869e+05
# ..           ...                    ...
# 66           NaN                    NaN
# 70           NaN                    NaN
# 71           NaN                    NaN
# 72           NaN                    NaN
# 76           NaN                    NaN
#
# [80 rows x 4 columns]

# %%
merged_sorted.to_csv("Release_to_PNEC_Ratios.csv", index=False)

# %%
# List of substances to extract
target_substances = [
    "Heptachlor",
    "Indeno(1,2,3-cd)pyrene",
    "Benzo(a)pyrene",
    "Cypermethrin",
    "Fluoranthene"
]

# Lowercase version for matching
target_substances_lower = [s.lower() for s in target_substances]

# Original DataFrame names, newest to oldest
df_names = [
    "df_no_gas", "df22_no_gas", "df21_no_gas", "df20_no_gas",
    "df19_no_gas", "df18_no_gas", "df17_no_gas", "df16_no_gas"
]

# Corresponding new variable names
new_names = ["d23", "d22", "d21", "d20", "d19", "d18", "d17", "d16"]

# Loop to filter and rename
for df_name, new_name in zip(df_names, new_names):
    df = globals()[df_name]
    df["SUBSTANCE NAME"] = df["SUBSTANCE NAME"].astype(str)
    filtered_df = df[df["SUBSTANCE NAME"].str.lower().isin(target_substances_lower)]
    globals()[new_name] = filtered_df
    print(f"{new_name} created with shape: {filtered_df.shape}")
# Out:
# d23 created with shape: (523, 19)
# d22 created with shape: (590, 15)
# d21 created with shape: (596, 15)
# d20 created with shape: (537, 15)
# d19 created with shape: (539, 15)
# d18 created with shape: (515, 15)
# d17 created with shape: (482, 15)
# d16 created with shape: (518, 15)

# %%
from pyproj import Proj, transform
#convert Easting/Northing to Latitude/Longitude
in_proj = Proj(init='epsg:27700')  #British National Grid
out_proj = Proj(init='epsg:4326')  #WGS84 (Latitude/Longitude)

#CONVERSION
def convert_coordinates(row):
    lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
    return pd.Series([lat, lon])

#df_no_gas_cleaned[['Latitude', 'Longitude']] = df_no_gas_cleaned.apply(convert_coordinates, axis=1)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\andre\anaconda3\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
d23[['Latitude', 'Longitude']] = d23.apply(convert_coordinates, axis=1)
d22[['Latitude', 'Longitude']] = d22.apply(convert_coordinates, axis=1)
d21[['Latitude', 'Longitude']] = d21.apply(convert_coordinates, axis=1)
d20[['Latitude', 'Longitude']] = d20.apply(convert_coordinates, axis=1)
d19[['Latitude', 'Longitude']] = d19.apply(convert_coordinates, axis=1)
d18[['Latitude', 'Longitude']] = d18.apply(convert_coordinates, axis=1)
d17[['Latitude', 'Longitude']] = d17.apply(convert_coordinates, axis=1)
d16[['Latitude', 'Longitude']] = d16.apply(convert_coordinates, axis=1)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d23[['Latitude', 'Longitude']] = d23.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d23[['Latitude', 'Longitude']] = d23.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d22[['Latitude', 'Longitude']] = d22.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d22[['Latitude', 'Longitude']] = d22.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d21[['Latitude', 'Longitude']] = d21.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d21[['Latitude', 'Longitude']] = d21.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d20[['Latitude', 'Longitude']] = d20.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d20[['Latitude', 'Longitude']] = d20.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d19[['Latitude', 'Longitude']] = d19.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d19[['Latitude', 'Longitude']] = d19.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d18[['Latitude', 'Longitude']] = d18.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d18[['Latitude', 'Longitude']] = d18.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d17[['Latitude', 'Longitude']] = d17.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d17[['Latitude', 'Longitude']] = d17.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\395054289.py:8: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lon, lat = transform(in_proj, out_proj, row['EASTING'], row['NORTHING'])
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d16[['Latitude', 'Longitude']] = d16.apply(convert_coordinates, axis=1)
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\2542310713.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d16[['Latitude', 'Longitude']] = d16.apply(convert_coordinates, axis=1)

# %%
import json
from shapely.geometry import shape, Point

# Load the GeoJSON file
with open("Regions_December_2024_Boundaries_EN_BFC_1195854647342073399 (1).geojson") as f:
    regions_geojson = json.load(f)

# Extract region polygons and names
region_shapes = []
for feature in regions_geojson["features"]:
    region_name = feature["properties"]["RGN24NM"]
    polygon = shape(feature["geometry"])
    region_shapes.append((region_name, polygon))

# Function to find which region a point belongs to
def get_region_for_point(lat, lon):
    point = Point(lon, lat)
    for name, polygon in region_shapes:
        if polygon.contains(point):
            return name
    return None

# List of in-memory DataFrame variable names
df_names = ["d23", "d22", "d21", "d20", "d19", "d18", "d17", "d16"]

# Apply region-matching to each DataFrame
for name in df_names:
    df = globals()[name]

    # Ensure latitude and longitude columns exist
    if "Latitude" in df.columns and "Longitude" in df.columns:
        # Convert to numeric and drop rows with missing coords
        df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
        df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
        df = df.dropna(subset=["Latitude", "Longitude"])

        # Apply region mapping
        df["REGION"] = df.apply(
            lambda row: get_region_for_point(row["Latitude"], row["Longitude"]),
            axis=1
        )

        # Update the variable in memory
        globals()[name] = df
        print(f"Updated regions for {name}")
    else:
        print(f"Skipped {name} (Latitude/Longitude columns not found)")
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
# Updated regions for d23
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
# Updated regions for d22
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
# Updated regions for d21
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
# Updated regions for d20
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
# Updated regions for d19
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
# Updated regions for d18
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
# Updated regions for d17
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")
# C:\Users\andre\AppData\Local\Temp\ipykernel_13608\3372488367.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")

# %%
# List of DataFrame names
df_names = ["d23", "d22", "d21", "d20", "d19", "d18", "d17", "d16"]

# Loop through each dataframe and count rows where REGION is NaN
for name in df_names:
    df = globals()[name]
    na_count = df["region"].isna().sum()
    print(f"{name} — Rows with REGION == NA: {na_count}")

# %%
d16
# Out:
#       authorisation id / permit id  \
# 116                       BR5035IT
# 221                       BJ7433IQ
# 225                        WRA7409
# 236                       BR4977IH
# 244                       BP3530RC
# ...                            ...
# 13109                     LP3232ZM
# 13124                     WP3537ZG
# 13125                     WP3537ZG
# 13159                     WP3537ZG
# 13299                     TP3039RN
#
#                    primary industry activity description  \
# 116    COATING, PRINTING AND TEXTILES; PRE-TREATING B...
# 221    PAPER, PULP AND BOARD; PRODUCING PAPER/BOARD >...
# 225                                                  NaN
# 236    COATING, PRINTING AND TEXTILES; PRE-TREATING B...
# 244    COATING, PRINTING AND TEXTILES; PRE-TREATING B...
# ...                                                  ...
# 13109  PAPER, PULP AND BOARD; PRODUCING PAPER/BOARD >...
# 13124  WASTE LANDFILLING; >10 T/D WITH CAPACITY >25,0...
# 13125  WASTE LANDFILLING; >10 T/D WITH CAPACITY >25,0...
# 13159  WASTE LANDFILLING; >10 T/D WITH CAPACITY >25,0...
# 13299  DISPOSAL OR RECOVERY OF HAZ WASTE WITH CAPACIT...
#
#                                     operator name  \
# 116                       Calder Textiles Limited
# 221                      Smurfit Kappa UK Limited
# 225              Yorkshire Water Services Limited
# 236                       Bulmer & Lumb Group Ltd
# 244    Harrison Gardner Dyers and Winders Limited
# ...                                           ...
# 13109        Northwood Tissue (Lancaster) Limited
# 13124             Octagon Green Solutions Limited
# 13125             Octagon Green Solutions Limited
# 13159             Octagon Green Solutions Limited
# 13299                Biffa Waste Services Limited
#
#                                             site address site postcode  \
# 116    Anchor House Thornhill Road Dewsbury West York...      WF12 9QE
# 221    Snodland Paper Mill Chp Mill Street Snodland Kent       ME6 5AX
# 225                                     HUDDERSFIELD STW       HD2 1FG
# 236    Buttershaw Textiles Royds Hall Lane Bradford W...       BD6 2NE
# 244    Royds Hall Lane Site Royds Hall Lane Buttersha...       BD6 2NE
# ...                                                  ...           ...
# 13109  Np. Lancaster Tissue Lansil Way Lansil Industr...       LA1 3QY
# 13124  Blaydon Quarry Landfill Lead Road Greenside Bl...      NE21 4SX
# 13125  Blaydon Quarry Landfill Lead Road Greenside Bl...      NE21 4SX
# 13159  Blaydon Quarry Landfill Lead Road Greenside Bl...      NE21 4SX
# 13299  Sheffield Waste Management Centre Holbrook Ris...       S20 3FG
#
#        easting  northing                        ea area name  \
# 116     424000    420500                           Yorkshire
# 221     570780    161600  Kent, South London and East Sussex
# 225     417124    419244                           Yorkshire
# 236     414340    429240                           Yorkshire
# 244     414300    429150                           Yorkshire
# ...        ...       ...                                 ...
# 13109   348510    463390              Cumbria and Lancashire
# 13124   416200    562600                          North East
# 13125   416200    562600                          North East
# 13159   416200    562600                          North East
# 13299   443960    381520                           Yorkshire
#
#               route name  substance name  reporting threshold (kg)  \
# 116           Wastewater    Cypermethrin                     0.005
# 221    Controlled Waters    Cypermethrin                     0.005
# 225    Controlled Waters    Cypermethrin                     0.005
# 236           Wastewater    Cypermethrin                     0.005
# 244           Wastewater    Cypermethrin                     0.005
# ...                  ...             ...                       ...
# 13109         Wastewater    Cypermethrin                     0.005
# 13124         Wastewater    Fluoranthene                     0.100
# 13125         Wastewater      Heptachlor                     0.100
# 13159         Wastewater  Benzo(a)pyrene                     1.000
# 13299  Controlled Waters    Cypermethrin                     0.005
#
#        quantity released (kg) regulated industry sector  \
# 116                   0.00800        Paper and textiles
# 221                   0.04628        Paper and textiles
# 225                   0.05000            Water Industry
# 236                   0.07310        Paper and textiles
# 244                   0.08800        Paper and textiles
# ...                       ...                       ...
# 13109                 0.00000        Paper and textiles
# 13124                 0.00000                  Landfill
# 13125                 0.00000                  Landfill
# 13159                 0.00000                  Landfill
# 13299                 0.00000           Waste treatment
#
#       regulated industry sub sector  pnec (µg/l)
# 116                        Textiles     0.000013
# 221                    Paper & Pulp     0.000013
# 225                  Water Industry     0.000013
# 236                        Textiles     0.000013
# 244                        Textiles     0.000013
# ...                             ...          ...
# 13109                  Paper & Pulp     0.000013
# 13124        Non Hazardous Landfill          NaN
# 13125        Non Hazardous Landfill          NaN
# 13159        Non Hazardous Landfill          NaN
# 13299                     Hazardous     0.000013
#
# [518 rows x 15 columns]

# %%
# List of filtered DataFrame variable names
filtered_names = ["d23", "d22", "d21", "d20", "d19", "d18", "d17", "d16"]

# Save each to a CSV
for name in filtered_names:
    df = globals()[name]
    filename = f"{name}.csv"
    df.to_csv(filename, index=False)
    print(f"Saved {name} to {filename}")
